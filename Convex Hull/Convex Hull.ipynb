# %% [markdown]
# # Convex Hull 101

# %% [markdown]
# ## An Example

# %%
import numpy as np
from scipy.spatial import ConvexHull
import matplotlib.pyplot as plt
% matplotlib notebook

# %%
numberOfData=40
pointCloud2D=0.1 + 0.8*np.random.rand(numberOfData, 2)
pointCloud2D
# Out:
# array([[ 0.76084067,  0.81560506],
#        [ 0.35594204,  0.51624985],
#        [ 0.46517569,  0.76122858],
#        [ 0.36996008,  0.30202104],
#        [ 0.40737958,  0.52476141],
#        [ 0.83061784,  0.51302887],
#        [ 0.54279972,  0.61494669],
#        [ 0.21041572,  0.57490868],
#        [ 0.50437255,  0.27338257],
#        [ 0.80208069,  0.58752484],
#        [ 0.50020425,  0.18060597],
#        [ 0.30693905,  0.84956347],
#        [ 0.42057434,  0.20155182],
#        [ 0.57400356,  0.16560541],
#        [ 0.48592157,  0.8924203 ],
#        [ 0.48899387,  0.87676199],
#        [ 0.43930668,  0.66457281],
#        [ 0.26119229,  0.32763309],
#        [ 0.6051423 ,  0.30432677],
#        [ 0.21466176,  0.11000617],
#        [ 0.8423006 ,  0.61795115],
#        [ 0.78686328,  0.267431  ],
#        [ 0.25194839,  0.38319957],
#        [ 0.15706021,  0.57380511],
#        [ 0.66727102,  0.46255695],
#        [ 0.80950497,  0.68321914],
#        [ 0.47148068,  0.63631622],
# ...

# %%
ch=ConvexHull(points=pointCloud2D)
ch

# %%
hullIndices=ch.vertices
hullIndicesEnclosed=np.concatenate([hullIndices,np.array([hullIndices[0]])])

# %%
plt.figure(1)
plt.scatter(x=pointCloud2D[:,0],y=pointCloud2D[:,1],label="data")
plt.plot(pointCloud2D[hullIndicesEnclosed,0],pointCloud2D[hullIndicesEnclosed,1],label="edges of the convex hull")
plt.title("Convex Hull of dataset")
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,...">
